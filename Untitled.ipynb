# %%
import seaborn as sns
import pandas as pd
import matplotlib.pyplot as plt
import numpy as np

# %%
sns.set_style('darkgrid')

# %%
from sklearn.model_selection import StratifiedShuffleSplit, train_test_split

# %%
train = pd.read_csv('train.csv')

# %%
df = train.copy()

# %%
ss = StratifiedShuffleSplit(n_splits=1, test_size = 0.3, random_state=42)

# %%
for train_index, test_index in ss.split(df, df['Promoted_or_Not']):
    train_ = df.loc[train_index]
    test_ = df.loc[test_index]

# %%
df_test = test_.copy()

# %%
df_train = train_.copy()

# %%
df_train.hist(figsize =(12,26))
# Out:
# array([[<matplotlib.axes._subplots.AxesSubplot object at 0x0000017C3FDA3550>,
# ...
#       dtype=object)

# %%
plt.figure(figsize=(12, 6))
sns.barplot(data =df_train, y='Training_score_average',x='Last_performance_score', hue= 'Promoted_or_Not')
# Out:
# C:\Users\9470m\Anaconda3\lib\site-packages\scipy\stats\stats.py:1713: FutureWarning: Using a non-tuple sequence for multidimensional indexing is deprecated; use `arr[tuple(seq)]` instead of `arr[seq]`. In the future this will be interpreted as an array index, `arr[np.array(seq)]`, which will result either in an error or a different result.
#   return np.add.reduce(sorted[indexer] * weights, axis=axis) / sumval

# %%
df.columns
# Out:
# Index(['EmployeeNo', 'Division', 'Qualification', 'Gender',
#        'Channel_of_Recruitment', 'Trainings_Attended', 'Year_of_birth',
#        'Last_performance_score', 'Year_of_recruitment', 'Targets_met',
#        'Previous_Award', 'Training_score_average', 'State_Of_Origin',
#        'Foreign_schooled', 'Marital_Status', 'Past_Disciplinary_Action',
#        'Previous_IntraDepartmental_Movement', 'No_of_previous_employers',
#        'Promoted_or_Not'],
#       dtype='object')

# %%
plt.figure(figsize=(12, 6))
sns.set_context("paper", rc={"axes.labelsize":12})
sns.countplot(data = df, x='Division', )

# %%
sns.countplot(data = df_train,x='Targets_met', hue='Promoted_or_Not')

# %%
sns.barplot(x=df_train['Promoted_or_Not'], y=df_train['Training_score_average'], hue=df_train['Foreign_schooled'])

# %%
df_train.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Int64Index: 26818 entries, 3406 to 12900
# Data columns (total 19 columns):
# EmployeeNo                             26818 non-null object
# Division                               26818 non-null object
# Qualification                          25653 non-null object
# Gender                                 26818 non-null object
# Channel_of_Recruitment                 26818 non-null object
# Trainings_Attended                     26818 non-null int64
# Year_of_birth                          26818 non-null int64
# Last_performance_score                 26818 non-null float64
# Year_of_recruitment                    26818 non-null int64
# Targets_met                            26818 non-null int64
# Previous_Award                         26818 non-null int64
# Training_score_average                 26818 non-null int64
# State_Of_Origin                        26818 non-null object
# Foreign_schooled                       26818 non-null object
# ...

# %%
sns.pairplot(df_train)

# %%
sns.scatterplot(x=df_train['Year_of_recruitment'],y=df_train['Year_of_birth'] ,hue= df_train['Promoted_or_Not'])

# %%
df_train.Promoted_or_Not.value_counts()
# Out:
# 0    24549
# 1     2269
# Name: Promoted_or_Not, dtype: int64

# %%
sns.countplot(df_train['Promoted_or_Not'])

# %%
sns.distplot(df_train['Year_of_recruitment'], bins=12,)

# %%
plt.figure(figsize=(10,6))
sns.distplot(df_train['Year_of_birth'], bins=12)

# %%
df1 = df_train.copy()

# %%
df1['Year_of_birth'] = (np.log10(df_train['Year_of_birth']))

# %%
sns.distplot(df1['Year_of_birth'], bins=12)

# %%
df1['Year_of_recruitment'] = (np.log10(df_train['Year_of_recruitment']))

# %%
sns.distplot(df1['Year_of_recruitment'], bins=12)

# %%
df_train.isnull().sum()
# Out:
# EmployeeNo                                0
# Division                                  0
# Qualification                          1165
# Gender                                    0
# Channel_of_Recruitment                    0
# Trainings_Attended                        0
# Year_of_birth                             0
# Last_performance_score                    0
# Year_of_recruitment                       0
# Targets_met                               0
# Previous_Award                            0
# Training_score_average                    0
# State_Of_Origin                           0
# Foreign_schooled                          0
# Marital_Status                            0
# Past_Disciplinary_Action                  0
# Previous_IntraDepartmental_Movement       0
# No_of_previous_employers                  0
# Promoted_or_Not                           0
# dtype: int64

# %%
plt.figure(figsize=(30, 12))
sns.set_context("paper", rc={"axes.labelsize":18})
sns.countplot(x= df_train['Division'], hue= df_train['Promoted_or_Not'])

# %%
df_train.Division.value_counts()
# Out:
# Commercial Sales and Marketing                 8233
# Customer Support and Field Operations          5546
# Sourcing and Purchasing                        3550
# Information Technology and Solution Support    3412
# Information and Strategy                       2638
# Business Finance Operations                    1258
# People/HR Management                           1193
# Regulatory and Legal services                   504
# Research and Innovation                         484
# Name: Division, dtype: int64

# %%
df_train.Promoted_or_Not.value_counts()
# Out:
# 0    24549
# 1     2269
# Name: Promoted_or_Not, dtype: int64

# %%
plt.figure(figsize=(12, 6))
sns.set_context("paper", rc={"axes.labelsize":12})
sns.countplot(x= df_train['Previous_IntraDepartmental_Movement'], hue= df_train['Promoted_or_Not'])

# %%
df_train.columns
# Out:
# Index(['EmployeeNo', 'Division', 'Qualification', 'Gender',
#        'Channel_of_Recruitment', 'Trainings_Attended', 'Year_of_birth',
#        'Last_performance_score', 'Year_of_recruitment', 'Targets_met',
#        'Previous_Award', 'Training_score_average', 'State_Of_Origin',
#        'Foreign_schooled', 'Marital_Status', 'Past_Disciplinary_Action',
#        'Previous_IntraDepartmental_Movement', 'No_of_previous_employers',
#        'Promoted_or_Not'],
#       dtype='object')

# %%
plt.figure(figsize=(12, 6))
sns.set_context("paper", rc={"axes.labelsize":12})
sns.countplot(x= df_train['Past_Disciplinary_Action'], hue= df_train['Promoted_or_Not'])

# %%
df_train.head()
# Out:
#         EmployeeNo                                     Division  \
# 3406   YAK/S/04785               Commercial Sales and Marketing
# 9297   YAK/S/13198               Commercial Sales and Marketing
# 21314  YAK/S/30424  Information Technology and Solution Support
# 13401  YAK/S/19077        Customer Support and Field Operations
# 6361   YAK/S/09002                     Information and Strategy
#
#              Qualification  Gender   Channel_of_Recruitment  \
# 3406      MSc, MBA and PhD    Male  Direct Internal process
# 9297   First Degree or HND    Male  Direct Internal process
# 21314  First Degree or HND  Female        Agency and others
# 13401  First Degree or HND  Female  Direct Internal process
# 6361   First Degree or HND    Male  Direct Internal process
#
#        Trainings_Attended  Year_of_birth  Last_performance_score  \
# 3406                    4           1988                     2.5
# 9297                    3           1983                     2.5
# ...

# %%
sns.scatterplot(x=df_train['Year_of_birth'], y=df_train['Training_score_average'], hue= df_train['Promoted_or_Not'])

# %%
sns.scatterplot(x= df_train['Year_of_birth'], y= df_train['Year_of_recruitment'], hue= df_train['Promoted_or_Not'])

# %%
df_num= df_train.dtypes != 'object'

# %%
df_numc = df_train.columns[df_num]

# %%
df_numc = df_numc.tolist()

# %%
df_corr = df_train[df_numc].corr()

# %%
df_corr['Promoted_or_Not'].sort_values()
# Out:
# Trainings_Attended       -0.021422
# Year_of_recruitment       0.015571
# Year_of_birth             0.017179
# Last_performance_score    0.119128
# Training_score_average    0.177504
# Previous_Award            0.203667
# Targets_met               0.227985
# Promoted_or_Not           1.000000
# Name: Promoted_or_Not, dtype: float64

# %%
df_corr['Targets_met'].sort_values()
# Out:
# Trainings_Attended       -0.043724
# Year_of_birth             0.024641
# Year_of_recruitment       0.077564
# Training_score_average    0.078320
# Previous_Award            0.092503
# Promoted_or_Not           0.227985
# Last_performance_score    0.277059
# Targets_met               1.000000
# Name: Targets_met, dtype: float64

# %%
df_corr['Previous_Award'].sort_values()
# Out:
# Trainings_Attended       -0.008325
# Year_of_birth             0.015447
# Last_performance_score    0.029054
# Year_of_recruitment       0.044605
# Training_score_average    0.073305
# Targets_met               0.092503
# Promoted_or_Not           0.203667
# Previous_Award            1.000000
# Name: Previous_Award, dtype: float64

# %%
plt.figure(figsize=(12,6))
sns.heatmap(df_corr)

# %%
sns.countplot(x= df_train['Previous_Award'])

# %%
plt.figure(figsize=(8,4))
sns.barplot(x= df_train['Previous_Award'], y=df_train['Training_score_average'], hue=df_train['Promoted_or_Not'] )

# %%
plt.figure(figsize=(8,4))
sns.barplot(x= df_train['Previous_IntraDepartmental_Movement'], y=df_train['Last_performance_score'], hue=df_train['Promoted_or_Not'] )

# %%
sns.countplot(x= df_train['Previous_IntraDepartmental_Movement'])

# %%
df_train.head(100)
# Out:
#         EmployeeNo                                     Division  \
# 3406   YAK/S/04785               Commercial Sales and Marketing
# 9297   YAK/S/13198               Commercial Sales and Marketing
# 21314  YAK/S/30424  Information Technology and Solution Support
# 13401  YAK/S/19077        Customer Support and Field Operations
# 6361   YAK/S/09002                     Information and Strategy
# 11087  YAK/S/15718                         People/HR Management
# 35121  YAK/S/50153                         People/HR Management
# 32351  YAK/S/46171                      Sourcing and Purchasing
# 27092  YAK/S/38661                      Sourcing and Purchasing
# 17555  YAK/S/25060                  Business Finance Operations
# 344    YAK/S/00489  Information Technology and Solution Support
# 28101  YAK/S/40132  Information Technology and Solution Support
# 18469  YAK/S/26339                  Business Finance Operations
# 36196  YAK/S/51731               Commercial Sales and Marketing
# ...

# %%
plt.figure(figsize=(8,4))
sns.countplot(df_train['Marital_Status'], hue= df_train['Promoted_or_Not'])

# %%
plt.figure(figsize=(8,4))
sns.countplot(df_train['Gender'])

# %%
sns.barplot(x=df_train['Gender'], y= df_train['Training_score_average'], hue= df_train['Promoted_or_Not'])

# %%
sns.barplot(x=df_train['Gender'], y= df_train['Last_performance_score'], hue= df_train['Promoted_or_Not'])
# Out:
# C:\Users\9470m\Anaconda3\lib\site-packages\scipy\stats\stats.py:1713: FutureWarning: Using a non-tuple sequence for multidimensional indexing is deprecated; use `arr[tuple(seq)]` instead of `arr[seq]`. In the future this will be interpreted as an array index, `arr[np.array(seq)]`, which will result either in an error or a different result.
#   return np.add.reduce(sorted[indexer] * weights, axis=axis) / sumval

# %%
df_corr.columns
# Out:
# Index(['Trainings_Attended', 'Year_of_birth', 'Last_performance_score',
#        'Year_of_recruitment', 'Targets_met', 'Previous_Award',
#        'Training_score_average', 'Promoted_or_Not'],
#       dtype='object')

# %%
df_corr['Previous_Award'].sort_values()
# Out:
# Trainings_Attended       -0.008325
# Year_of_birth             0.015447
# Last_performance_score    0.029054
# Year_of_recruitment       0.044605
# Training_score_average    0.073305
# Targets_met               0.092503
# Promoted_or_Not           0.203667
# Previous_Award            1.000000
# Name: Previous_Award, dtype: float64

# %%
df_train.Targets_met.value_counts()
# Out:
# 0    17314
# 1     9504
# Name: Targets_met, dtype: int64

# %%
sns.countplot(df_train['Targets_met'], hue= df_train['Promoted_or_Not'])

# %%
sns.countplot(df_train['Targets_met'], hue= df_train['Marital_Status'])

# %%
df_train.Previous_Award.value_counts()
# Out:
# 0    26190
# 1      628
# Name: Previous_Award, dtype: int64

# %%
sns.jointplot(x=df_train['Year_of_birth'], y=df_train['Training_score_average'], kind='hex')

# %%
df.Qualification.value_counts()
# Out:
# First Degree or HND         25578
# MSc, MBA and PhD            10469
# Non-University Education      586
# Name: Qualification, dtype: int64

# %%
sns.countplot(df_train['Qualification'], hue= df_train['Promoted_or_Not'])

# %%
df_train.isnull().sum()
# Out:
# EmployeeNo                                0
# Division                                  0
# Qualification                          1165
# Gender                                    0
# Channel_of_Recruitment                    0
# Trainings_Attended                        0
# Year_of_birth                             0
# Last_performance_score                    0
# Year_of_recruitment                       0
# Targets_met                               0
# Previous_Award                            0
# Training_score_average                    0
# State_Of_Origin                           0
# Foreign_schooled                          0
# Marital_Status                            0
# Past_Disciplinary_Action                  0
# Previous_IntraDepartmental_Movement       0
# No_of_previous_employers                  0
# Promoted_or_Not                           0
# dtype: int64

# %%
df2 = df_train.copy()

# %%
df2['Qualification'] = df2.Qualification.fillna('Non-University Education')

# %%
df2.Qualification.value_counts()
# Out:
# First Degree or HND         17927
# MSc, MBA and PhD             7326
# Non-University Education     1565
# Name: Qualification, dtype: int64

# %%
df3 = df_train.copy()

# %%
df3['Qualification'] = df3.Qualification.fillna('First Degree or HND')

# %%
df3['Qualification'].value_counts()
# Out:
# First Degree or HND         19092
# MSc, MBA and PhD             7326
# Non-University Education      400
# Name: Qualification, dtype: int64

# %%
qualifaction_map = {'First Degree or HND': 0, 'Non-University Education': 0, 'MSc, MBA and PhD': 1}

# %%
states_to_geozone = {
    'ABIA': "SW",
    'ADAMAWA': "NE",
    'AKWA IBOM': "SS",
    'ANAMBRA': "SE",
    'BAUCHI': "NE",
    'BAYELSA': "SS",
    'BENUE': "NC",
    'BORNO': "NE",
    'CROSS RIVER': "SS",
    'DELTA': "SS",
    'EBONYI': "SE",
    'EDO': "SS",
    'EKITI': "SW",
    'ENUGU': "SE",
    'FCT': "NC",
    'GOMBE': "NC",
    'IMO': "SE",
    'JIGAWA': "NW",
    'KADUNA': "NW",
    'KANO': 'NW',
    'KATSINA': "NW",
    'KEBBI': "NW",
    'KOGI': "NC",
    'KWARA': "NC",
    "LAGOS": "SW",
    'NASSARAWA': "NC",
    'NIGER': "NC",
     'OGUN': "SW",
     'ONDO': "SW",
     'OSUN': "SW",
     'OYO': "SW",
     'PLATEAU': "NC",
     'RIVERS': "SS",
     'SOKOTO': "NW",
     'TARABA': "NE",
     'YOBE': "NE",
     'ZAMFARA': "NE"
    }

# %%
division_to_numbers = {'Commercial Sales and Marketing':1,'Customer Support and Field Operations':2,
                       'Sourcing and Purchasing':3,'Information Technology and Solution Support':4,
                       'Information and Strategy':5,'Business Finance Operations':6,'People/HR Management':7,
                       'Regulatory and Legal services': 8, 'Research and Innovation': 9}

# %%
def age_class(year_of_birth):

# %%
plt.figure(figsize=(10,5))
sns.scatterplot(y= df_train['Year_of_birth'], x= df_train['Year_of_recruitment'], hue= df_train['Promoted_or_Not'])

# %%
def recruitment_bin(year_of_recruitment):
    year = int(year_of_recruitment)
    
    if year >= 2010 and year <= 2018:
        return 'recent_recruits'
    else:
        return 'later_recruits'

# %%
df3['Year_of_recruitment'] = recruitment_bin(df3['Year_of_recruitment'])
# Out:
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# <ipython-input-97-84a1837b22fe> in <module>
# ----> 1 df3['Year_of_recruitment'] = recruitment_bin(df3['Year_of_recruitment'])
#
# <ipython-input-96-fccc0d1fd24e> in recruitment_bin(year_of_recruitment)
#       1 def recruitment_bin(year_of_recruitment):
# ----> 2     year = int(year_of_recruitment)
#       3
#       4     if year >= 2010 and year <= 2018:
#       5         return 'recent_recruits'
#
# ~\Anaconda3\lib\site-packages\pandas\core\series.py in wrapper(self)
#     116             return converter(self.iloc[0])
#     117         raise TypeError("cannot convert the series to "
# --> 118                         "{0}".format(str(converter)))
#     119
#     120     return wrapper
#
# TypeError: cannot convert the series to <class 'int'>
